# %% [markdown]
# # INSTALL MLIP-LAMMPS WITH INTEL 2021.5.0 ON NSM CLUSTER, IIT KANPUR

# %%
#tried with intel 2021.5.0
source /opt/ohpc/pub/compiler/intel/oneapi/setvars.sh intel64

cd ~/software/mlp/mlip
./configure

#output
Generating makefile configuration ...
Configuration complete.

make mlp
#output
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/bfgs.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/common/bfgs.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/utils.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/common/utils.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/stdafx.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/common/stdafx.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/drivers/basic_drivers.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/drivers/basic_drivers.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/drivers/relaxation.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/drivers/relaxation.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/lammps_potential.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/lammps_potential.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mtp.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtp.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/neighborhoods.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/neighborhoods.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/configuration.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/configuration.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlip_wrapper.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlip_wrapper.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_trainer.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_trainer.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/active_learning.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/active_learning.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_mlip.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_mlip.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_potentials.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_potentials.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/lotf.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/lotf.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/vasp_potential.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/vasp_potential.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/linear_regression.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/linear_regression.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/pair_potentials.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/pair_potentials.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/error_monitor.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/error_monitor.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/radial_basis.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/radial_basis.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/maxvol.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/maxvol.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlp/mlp_commands.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mlp_commands.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlp/train.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/train.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlp/calc_errors.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/calc_errors.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlp/self_test.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/self_test.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/eam.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/eam.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/sw_basis.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/sw_basis.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mtpr.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtpr.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mtpr_trainer.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtpr_trainer.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/non_linear_regression.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/non_linear_regression.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/matvec_oper.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/matvec_oper.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mlp/mtpr_train.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mtpr_train.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mlp/dev_mlp_commands.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/dev_mlp_commands.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mlp/mlp.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mlp.cpp.o
mpiicpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -MMD  -DMLIP_MPI -DMLIP_INTEL_MKL  -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mlp/dev_self_test.cpp -o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/dev_self_test.cpp.o
mpiicpc /home/nirajd/softwares/mlp/mlip/obj/mpi/common/bfgs.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/common/utils.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/common/stdafx.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/drivers/basic_drivers.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/drivers/relaxation.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/lammps_potential.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtp.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/neighborhoods.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/configuration.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlip_wrapper.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_trainer.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/active_learning.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_mlip.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/basic_potentials.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/lotf.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/vasp_potential.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/linear_regression.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/pair_potentials.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/error_monitor.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/radial_basis.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/maxvol.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mlp_commands.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/train.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/calc_errors.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/self_test.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/eam.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/sw_basis.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtpr.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mtpr_trainer.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/non_linear_regression.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/matvec_oper.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mtpr_train.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/dev_mlp_commands.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/mlp.cpp.o /home/nirajd/softwares/mlp/mlip/obj/mpi/mlp/dev_self_test.cpp.o -L/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/lib/intel64 -lmkl_rt -lifcore  -o bin/mlp

# you can find the binary file at this path: ./bin/mlp

make libinterface
#output
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/bfgs.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/common/bfgs.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/utils.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/common/utils.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/common/stdafx.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/common/stdafx.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/drivers/basic_drivers.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/drivers/basic_drivers.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/drivers/relaxation.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/drivers/relaxation.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/lammps_potential.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/lammps_potential.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mtp.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/mtp.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/neighborhoods.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/neighborhoods.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/configuration.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/configuration.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/mlip_wrapper.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/mlip_wrapper.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_trainer.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_trainer.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/active_learning.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/active_learning.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_mlip.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_mlip.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/basic_potentials.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_potentials.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/lotf.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/lotf.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/vasp_potential.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/vasp_potential.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/linear_regression.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/linear_regression.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/pair_potentials.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/pair_potentials.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/error_monitor.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/error_monitor.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/radial_basis.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/radial_basis.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/maxvol.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/maxvol.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/src/external/interface.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/external/interface.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/eam.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/eam.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/sw_basis.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/sw_basis.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mtpr.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/mtpr.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/mtpr_trainer.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/mtpr_trainer.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/non_linear_regression.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/non_linear_regression.cpp.o
icpc -O3  -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include -fPIC -MMD  -DMLIP_INTEL_MKL -fPIC -std=c++11 -DMLIP_DEV -c /home/nirajd/softwares/mlp/mlip/dev_src/matvec_oper.cpp -o /home/nirajd/softwares/mlp/mlip/obj/ser/matvec_oper.cpp.o
ar -rs lib/lib_mlip_interface.a /home/nirajd/softwares/mlp/mlip/obj/ser/common/bfgs.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/common/utils.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/common/stdafx.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/drivers/basic_drivers.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/drivers/relaxation.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/lammps_potential.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/mtp.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/neighborhoods.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/configuration.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/mlip_wrapper.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_trainer.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/active_learning.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_mlip.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/basic_potentials.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/lotf.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/vasp_potential.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/linear_regression.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/pair_potentials.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/error_monitor.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/radial_basis.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/maxvol.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/external/interface.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/eam.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/sw_basis.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/mtpr.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/mtpr_trainer.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/non_linear_regression.cpp.o /home/nirajd/softwares/mlp/mlip/obj/ser/matvec_oper.cpp.o
ar: creating lib/lib_mlip_interface.a

# check the lib_mlip_interface.a formed
ls lib/

make test

#output
INTEGRATION TESTING:
Running test 00.convert_vasp_outcar
Running test 01.train
Running test 02.calc-efs
Running test 03.calc-errors
Running test 04.calc-grade
Running test 05.select-add
Running test 06.relax
Running test 07.relax-active-learning
Running test 01.convert-cfg
Running test 02.convert-cfg
Running test 03.convert-cfg
Running test 04.convert-cfg
Running test 05.convert-cfg
Running test 06.convert-cfg
Running test 07.convert-cfg
Running test 07a.convert-cfg
Running test 08.convert-cfg
Running test 09.convert-cfg
Running test 10.convert-cfg
Running test 11.convert-cfg
Running test 12.convert-cfg
Running test 13.convert-cfg
Running test 14.convert-cfg
Running test 15.convert-cfg
Running self test
Note: self-test is running without #define MLIP_DEBUG;
      build with -DMLIP_DEBUG and run if troubles encountered
Serial pub tests:
  Test  1 passed (configurations reading)
  Test  2 passed (Binary and normal configurations reading)
  Test  3 passed (Loading configuration database to a vector)
  Test  4 passed (Binary configurations file format and old format r/w)
  Test  5 passed (New format configurations reading/writing test)
  Test  6 passed (Identical configurations reading test)
  Test  7 passed (Testing Configuration periodic extension)
  Test  8 passed (Testing reading configuration with fractional coordinates)
  Test  9 passed (Testing Configuration::features)
  Test 10 passed (VASP OUTCAR iterations count)
  Test 11 passed (BLAS_test)
  Test 12 passed (Errorneus configurations reading test)
  Test 13 passed (VASP loading)
  Test 14 passed (MTP file format v1.1.0 test)
  Test 15 passed (MTP file reading 1)
  Test 16 passed (MTP file reading 2)
  Test 17 passed (MTP file reading 3)
  Test 18 passed (MTP learning)
MPI pub tests (1 cores):
Note: self-test is running without #define MLIP_DEBUG;
      build with -DMLIP_DEBUG and run if troubles encountered
Serial pub tests:
  Test  1 passed (configurations reading)
  Test  2 passed (Binary and normal configurations reading)
  Test  3 passed (Loading configuration database to a vector)
  Test  4 passed (Binary configurations file format and old format r/w)
  Test  5 passed (New format configurations reading/writing test)
  Test  6 passed (Identical configurations reading test)
  Test  7 passed (Testing Configuration periodic extension)
  Test  8 passed (Testing reading configuration with fractional coordinates)
  Test  9 passed (Testing Configuration::features)
  Test 10 passed (VASP OUTCAR iterations count)
  Test 11 passed (BLAS_test)
  Test 12 passed (Errorneus configurations reading test)
  Test 13 passed (VASP loading)
  Test 14 passed (MTP file format v1.1.0 test)
  Test 15 passed (MTP file reading 1)
  Test 16 passed (MTP file reading 2)
  Test 17 passed (MTP file reading 3)
  Test 18 passed (MTP learning)
Serial dev tests:
  Test  1 passed (EAMSimple CalcEnergyGrad test by finite difference)
  Test  2 passed (EAMSimple CalcEFS check with finite differences)
  Test  3 passed (EAMSimple AddLossGrad test by finite difference)
  Test  4 passed (EAMMult CalcEFS check with finite differences)
  Test  5 passed (EAMMult AddLossGrad test by finite difference)
  Test  6 passed (Lennard-Jones CalcEFS check with finite differences)
  Test  7 passed (Lennard-Jones AddLossGrad test by finite difference)
  Test  8 passed (NonlinearLennard-Jones CalcEFS check with finite differences)
  Test  9 passed (NonlinearLennard-Jones AddLossGrad test by finite difference)
  Test 10 passed (PairPot AddLossGrad test by finite difference)
  Test 11 passed (MTPR CalcEFS (check forces correctness by using of central d)
  Test 12 passed (Linesearch)
  Test 13 passed (checks minimal distance in configurations)
  Test 14 passed (Supercell rotation test)
  Test 15 passed (Relaxation driver test)
  Test 16 passed (Robustness of relaxation with changing potential)
  Test 17 passed (Another MTP learning + ErrorMonitor)
  Test 18 passed (MTP fitting on insufficient data)
  Test 19 passed (MaxVol initialization and selection)
  Test 20 passed (MaxVol evaluation)
  Test 21 passed (Configurations motion while MaxVol selection)
  Test 22 passed (Maxvol selection UniqueCfgCnt() and swap_limit tests)
  Test 23 passed (Multiple selection test#1)
  Test 24 passed (Multiple selection test#2)
  Test 25 passed (MaxVol Saving/Loading selection test#1)
  Test 26 passed (MaxVol learning on the fly)
  Test 27 passed (check radial basis derivatives with finite differences)
MPI pub tests (1 cores):
MPI dev tests (1 cores):
  Test 28 passed (training PairPotentialNonlinear)
  Test 29 passed (EAMSimple fitting test)
  Test 30 passed (EAMMult fitting test)
  Test 31 passed (Lennard-Jones fitting test)
  Test 32 passed (NonlinearLennard-Jones fitting test)
  Test 33 passed (MTPR fitting test)
  Test 34 passed (MTPR loss gradient test)

# %%
# install 2022-06-22 18:08	  lammps-stable.tar.gz (https://download.lammps.org/tars/index.html)

scp -rp 4422 ~/Downloads/lammps-stable.tar.gz nirajd@paramsanganak.iitk.ac.in:/home/nirajd # transfer file to cluster
ssh -X -p 4422 nirajd@paramsanganak.iitk.ac.in # login into NSM
mv ~/lammps-stable.tar.gz ~/softwares/mlp
tar -zxvf lammps-stable.tar.gz
mv lammps-23Jun2022 lammps2022
mv lammps2022 ~/softwares/mlp

# %%
cd ~/softwares/mlp
git clone https://gitlab.com/ashapeev/interface-lammps-mlip-2.git interface

mv ~/softwares/mlp/mlip/lib/lib_mlip_interface.a ../interface/
cd ~/softwares/mlp/interfaces/

# edit preinstall.sh file and add these at the end
vi preinstall.sh

"make yes-MC
make yes-MEAM
make yes-manybody"

./install.sh ../lammps2022 intel_cpu_intelmpi

#OUTPUT
/home/nirajd/softwares/mlp/interface
Uninstalling package user-mlip
Installing package user-mlip
Installing package MC
Installing package MEAM
Installing package manybody
make[1]: Entering directory `/home/nirajd/softwares/mlp/lammps2022/src/STUBS'
rm -f *.o libmpi_stubs.a
make[1]: Leaving directory `/home/nirajd/softwares/mlp/lammps2022/src/STUBS'
make[1]: Entering directory `/home/nirajd/softwares/mlp/lammps2022/src/STUBS'
g++ -O -fPIC -I.  -c mpi.cpp
ar rs libmpi_stubs.a mpi.o
ar: creating libmpi_stubs.a
make[1]: Leaving directory `/home/nirajd/softwares/mlp/lammps2022/src/STUBS'
Gathering installed package information (may take a little while)
make[1]: Entering directory `/home/nirajd/softwares/mlp/lammps2022/src'
Gathering git version information
make[1]: Leaving directory `/home/nirajd/softwares/mlp/lammps2022/src'
Compiling LAMMPS for machine intel_cpu_intelmpi
make[1]: Entering directory `/home/nirajd/softwares/mlp/lammps2022/src/Obj_intel_cpu_intelmpi'
make[1]: Leaving directory `/home/nirajd/softwares/mlp/lammps2022/src/Obj_intel_cpu_intelmpi'
make[1]: Entering directory `/home/nirajd/softwares/mlp/lammps2022/src/Obj_intel_cpu_intelmpi'
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../main.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_bin_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_erotate_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_skip.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_old_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_external.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../math_special.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../finish.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../variable.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../image.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_skip_respa.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_histo.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../tokenizer.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../displace_atoms.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../reader_xyz.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_bin_ghost.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_airebo_morse.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_airebo.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../rerun.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_quickmin.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_chunk_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_bin_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../math_extra.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_qeq_comb.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_nsq_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_buck.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_charge.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_rdf.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../table_file_reader.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_rebo.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_multi.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../lattice.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../write_dump.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_nsq.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../input.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_bin_atomonly.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_angle_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nbin.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_plane.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../kspace_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_nsq_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_halffull_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nph_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_lineforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_region.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_fire.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../create_box.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_store_state.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_lj_expand.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_vcm_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_gyration_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../comm_brick.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_bond_create.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_line.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_gw_zbl.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_buck_coul_cut.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_pair_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance_var.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_dt_reset.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_partial.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_tersoff_table.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_setup_done.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_vacf.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_setup_param.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_nsq_newtoff_ghost.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../my_page.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_addforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../write_data.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_centroid_stress_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_histo_weight.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_meam_sw_spline.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_store_force.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_block.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_reduce_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../universe.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../bond_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_property_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_coord_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../special.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_hybrid_overlay.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_ke_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../respa.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dihedral_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_copy.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_multi_old_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_chunk_spread_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_minimize.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../improper_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_lj1043.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_improper_all.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../change_box.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_prism.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_body.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_spring_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nvt_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_dipole.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_multi_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_nsq_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_respa_nsq_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../read_dump.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../run.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../group.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_xyz.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eam_alloy.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_coul_wolf.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_heat.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_force.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_old_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nve_limit.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_temp_berendsen.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_profile.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_born.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_multi_old.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_aveforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_viscous.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_gw.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_move.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_bin_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_neigh_history.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_bond_break.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../create_atoms.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../gridcomm.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_map.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../replicate.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_angle_partial.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nve.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_threebody_table.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_read_restart.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../timer.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_nsq_ghost.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../tabular_function.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_store.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_ghost_bin_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_tfmc.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_comb3.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../reset_mol_ids.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_box_relax.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_coul_dsf.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_reduce_region.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../thermo.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_setup_global.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../improper_zero.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_intersect.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_langevin.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nvt.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../body.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_full_bin.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_correlate.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../bond.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_cna_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_slice.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_old_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_msd.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_angle_template.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_reduce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_multi_old_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_old_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dihedral.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_dihedral_partial.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance_time.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../my_pool_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../create_bonds.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_temp_rescale.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../neighbor.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_table.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_vector.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../write_restart.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_deform.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../write_coeff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../neigh_list.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../velocity.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_cg.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../procmap.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_bop.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance_store.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance_neigh.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_reflect.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_tersoff_mod_c.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_respa_nsq_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_deposit.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_dihedral_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eam_he.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_spring.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_erotate_sphere_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../rcb.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nh.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_old_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_property_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../random_mars.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_displace_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_bin_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_dens_init.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_impl.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_movie.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../update.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_improper_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_bin_3d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_dihedral_all.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_morse.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../citeme.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../random_park.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../set.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_npt_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_cylinder.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_balance.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_hybrid_scaled.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_bond.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_momentum.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_bond_history.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_sw.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_update_special_bonds.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_torque_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_coul_debye.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_inertia_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_group.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_npt.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../lmppython.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_fire_old.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_fragment_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_property_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_time.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../angle_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nve_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../verlet.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eam_fs.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_sd.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../kspace.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_meam_spline.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_sw_angle_table.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../integrate.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_ellipsoid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_old_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_com.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_ke.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_coul_cut.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_stress_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_adapt.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_bond_swap.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fmtlib_os.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_yukawa.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_ramp.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_edip.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../reader_native.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_atomic.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_extep.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_restrain.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_bin_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_cluster_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dihedral_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../reset_atom_ids.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_bin_atomonly_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_orientorder_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_adp.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../bond_zero.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_sw_mod.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_3d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_cfg.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../angle.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dihedral_zero.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_bond_all.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_vashishta_table.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_morse.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_ave_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_lj126.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../info.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_edip_multi.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_respa_bin_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_com.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../irregular.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_bin_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_store_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_thermal_conductivity.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../memory.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_skip_size_off2on_oneside.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_tersoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_bin_newtoff_ghost.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_setforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_atm.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_bin_2d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_angmom_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../minimize.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nh_sphere.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_recenter.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_lj93.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_local_density.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../reader.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_lj_cut.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../read_restart.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_gcmc.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_ellipsoid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_centro_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_dipole_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../potential_file_reader.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_efield.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../output.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../comm.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_halffull_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_meam.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../neigh_request.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_indent.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../domain.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_improper.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../read_data.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_mol_swap.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_enforce2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../lammps.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_bond_create_angle.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_nb3b_harmonic.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../utils.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_custom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_lj_cut_coul_cut.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_evaporate.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_pe.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_gyration.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_old_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../imbalance_group.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_skip_size.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_multi_old_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../molecule.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nph.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_heat_flux.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_MLIP.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_deform.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_old_3d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eim.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../error.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_bond_partial.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_omega_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_polymorphic.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_union.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eam_cd.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_ghost_bin_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../delete_bonds.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_global_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_tersoff_mod.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_improper_partial.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../region_cone.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../improper.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_bin_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_com_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../math_eigen.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../hashlittle.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_linesearch.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_2d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nbin_multi.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_press_berendsen.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_print.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../arg_info.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_bond_template.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_dihedral_template.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_lcbop.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_gravity.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_msd_chunk.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nvt_sllod.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_improper_template.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../comm_tiled.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_property_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../force.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../modify.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_soft.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_multi_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_atom_swap.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../library.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_spring_self.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_nve_noforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../angle_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_angle.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_planeforce.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_funcs.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_dummy.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../balance.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_pe_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_zbl.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_skip_size_off2on.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../min_hftn.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_halt.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_zero.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp_region.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../angle_zero.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_wall_harmonic.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../atom_vec.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_tersoff_zbl.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../bond_hybrid.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_aggregate_atom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_respa.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_comb.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_eam.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../platform.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_full_bin_2d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../dump_image.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_size_bin_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_respa_bin_newton.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../improper_deprecated.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_pair.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_temp.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_pressure.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nbin_standard.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_multi_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_widom.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fix_charge_regulation.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_nsq_newtoff.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../delete_atoms.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_bin_3d.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_dsmc.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_dihedral.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../text_file_reader.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../pair_vashishta.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../meam_dens_final.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../nstencil_half_multi_old_2d_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../fmtlib_format.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_bond_local.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../npair_half_respa_bin_newton_tri.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../compute_group_group.cpp
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -qno-offload -ansi-alias -restrict -DLMP_INTEL_USELRT -DLMP_USE_MKL_RNG -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -I/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/include  -DLAMMPS_GZIP -I../../lib/mlip  -DMPICH_SKIP_MPICXX -DOMPI_SKIP_MPICXX=1 -DFFT_MKL -DFFT_SINGLE  -lgfortran  -c ../ntopo_angle_all.cpp
ar -rc ../liblammps_intel_cpu_intelmpi.a npair_half_bin_newton_tri.o npair_half_size_multi_newtoff.o compute_erotate_sphere.o npair_skip.o npair_half_multi_old_newton_tri.o fix_external.o math_special.o finish.o variable.o fix_deprecated.o image.o npair_skip_respa.o fix_ave_histo.o tokenizer.o displace_atoms.o reader_xyz.o pair_deprecated.o npair_full_bin_ghost.o pair_airebo_morse.o pair_airebo.o rerun.o atom.o min_quickmin.o compute_chunk_atom.o npair_half_size_bin_newtoff.o math_extra.o fix_qeq_comb.o npair_half_size_nsq_newtoff.o pair_buck.o atom_vec_charge.o compute_deprecated.o compute_rdf.o table_file_reader.o pair_rebo.o npair_full_multi.o lattice.o write_dump.o npair_full_nsq.o input.o npair_full_bin_atomonly.o compute_angle_local.o nbin.o region_plane.o kspace_deprecated.o npair_half_nsq_newton.o npair_halffull_newton.o fix_nph_sphere.o fix_lineforce.o fix_wall_region.o min_fire.o create_box.o fix_store_state.o pair_lj_expand.o compute_temp_sphere.o compute_vcm_chunk.o compute_gyration_chunk.o comm_brick.o fix_bond_create.o atom_vec_line.o fix_wall.o pair_gw_zbl.o pair_buck_coul_cut.o compute_pair_local.o imbalance_var.o fix_dt_reset.o compute_temp_partial.o pair_tersoff_table.o meam_setup_done.o compute_vacf.o meam_setup_param.o npair_half_nsq_newtoff_ghost.o my_page.o fix_addforce.o write_data.o compute_centroid_stress_atom.o fix_ave_histo_weight.o pair_meam_sw_spline.o fix_store_force.o region_block.o compute_reduce_chunk.o universe.o bond_deprecated.o compute_property_chunk.o compute_coord_atom.o special.o pair_hybrid_overlay.o compute_ke_atom.o respa.o dihedral_deprecated.o region_deprecated.o npair_copy.o nstencil_full_multi_old_3d.o compute_chunk_spread_atom.o fix_minimize.o improper_hybrid.o fix_wall_lj1043.o ntopo_improper_all.o change_box.o dump_local.o region_prism.o atom_vec_body.o fix_spring_chunk.o fix_nvt_sphere.o compute_dipole.o nstencil_full_multi_2d.o npair_half_size_multi_newton.o npair_half_size_nsq_newton.o npair_half_respa_nsq_newton.o read_dump.o run.o group.o dump_xyz.o pair_eam_alloy.o nstencil_half_multi_3d.o pair_coul_wolf.o fix_heat.o meam_force.o npair_half_multi_old_newtoff.o fix_nve_limit.o fix_temp_berendsen.o compute_temp_profile.o pair_born.o fix_ave_chunk.o npair_full_multi_old.o fix_aveforce.o fix_viscous.o npair_half_multi_newton_tri.o pair_gw.o fix_move.o nstencil_half_bin_2d.o fix_neigh_history.o fix_bond_break.o create_atoms.o ntopo.o gridcomm.o atom_map.o replicate.o ntopo_angle_partial.o fix_nve.o pair_threebody_table.o fix_read_restart.o timer.o npair_full_nsq_ghost.o tabular_function.o fix_store.o nstencil_full_ghost_bin_3d.o fix_tfmc.o pair_comb3.o reset_mol_ids.o fix_box_relax.o pair_coul_dsf.o compute_reduce_region.o thermo.o meam_setup_global.o improper_zero.o region_sphere.o region_intersect.o fix_langevin.o fix_nvt.o body.o npair_full_bin.o fix_ave_correlate.o bond.o compute_cna_atom.o compute_slice.o nstencil_half_multi_old_2d.o compute_msd.o ntopo_angle_template.o compute_reduce.o nstencil_full_multi_old_2d.o npair_half_size_multi_old_newton.o dihedral.o region.o ntopo_dihedral_partial.o imbalance_time.o my_pool_chunk.o create_bonds.o fix_temp_rescale.o neighbor.o pair_table.o fix_vector.o dump_deprecated.o write_restart.o compute_temp_deform.o write_coeff.o neigh_list.o velocity.o min_cg.o procmap.o pair_bop.o imbalance_store.o imbalance_neigh.o fix_wall_reflect.o pair_tersoff_mod_c.o npair_half_respa_nsq_newtoff.o fix_deposit.o compute_dihedral_local.o pair_eam_he.o fix_spring.o compute_erotate_sphere_atom.o rcb.o fix_nh.o nstencil_half_multi_old_3d.o fix_property_atom.o fix.o random_mars.o compute_displace_atom.o npair.o npair_half_bin_newton.o dump.o meam_dens_init.o meam_impl.o dump_movie.o update.o compute_improper_local.o nstencil_half_bin_3d_tri.o ntopo_dihedral_all.o pair_morse.o citeme.o atom_vec_hybrid.o random_park.o set.o fix_npt_sphere.o region_cylinder.o fix_balance.o pair_hybrid_scaled.o compute_bond.o fix_momentum.o fix_bond_history.o pair_sw.o fix_update_special_bonds.o compute_torque_chunk.o pair.o pair_coul_debye.o compute_inertia_chunk.o fix_group.o fix_npt.o lmppython.o min_fire_old.o compute_fragment_atom.o compute_property_atom.o fix_ave_time.o compute.o atom_vec_sphere.o angle_deprecated.o fix_nve_sphere.o verlet.o pair_eam_fs.o min_sd.o kspace.o pair_meam_spline.o pair_sw_angle_table.o integrate.o compute_temp_chunk.o atom_vec_ellipsoid.o npair_half_size_multi_old_newtoff.o nstencil_half_multi_2d.o compute_com.o compute_ke.o pair_coul_cut.o compute_stress_atom.o fix_adapt.o fix_bond_swap.o fmtlib_os.o pair_yukawa.o compute_temp_ramp.o pair_edip.o npair_half_multi_newton.o reader_native.o atom_vec_atomic.o npair_half_size_multi_newton_tri.o pair_extep.o fix_restrain.o nstencil_full_bin_3d.o compute_cluster_atom.o dihedral_hybrid.o reset_atom_ids.o npair_half_bin_atomonly_newton.o dump_atom.o compute_orientorder_atom.o pair_adp.o bond_zero.o deprecated.o pair_sw_mod.o nstencil_half_multi_3d_tri.o dump_cfg.o angle.o dihedral_zero.o ntopo_bond_all.o pair_vashishta_table.o fix_wall_morse.o fix_ave_atom.o fix_wall_lj126.o info.o pair_edip_multi.o atom_vec_tri.o npair_half_respa_bin_newtoff.o compute_temp_com.o irregular.o npair_half_size_bin_newton_tri.o fix_store_local.o fix_thermal_conductivity.o memory.o npair_skip_size_off2on_oneside.o pair_tersoff.o npair_half_bin_newtoff_ghost.o fix_setforce.o pair_atm.o nstencil_half_bin_2d_tri.o compute_angmom_chunk.o minimize.o fix_nh_sphere.o fix_recenter.o fix_wall_lj93.o pair_local_density.o reader.o pair_lj_cut.o read_restart.o fix_gcmc.o region_ellipsoid.o compute_centro_atom.o compute_dipole_chunk.o potential_file_reader.o fix_efield.o output.o comm.o npair_halffull_newtoff.o pair_meam.o neigh_request.o fix_indent.o domain.o compute_improper.o read_data.o fix_mol_swap.o fix_enforce2d.o lammps.o fix_bond_create_angle.o pair_nb3b_harmonic.o utils.o dump_custom.o pair_lj_cut_coul_cut.o imbalance.o fix_evaporate.o compute_pe.o compute_gyration.o npair_half_multi_old_newton.o imbalance_group.o nstencil.o npair_skip_size.o npair_half_size_multi_old_newton_tri.o molecule.o fix_nph.o compute_heat_flux.o pair_MLIP.o fix_deform.o nstencil_half_multi_old_3d_tri.o pair_eim.o error.o ntopo_bond_partial.o compute_omega_chunk.o pair_polymorphic.o region_union.o pair_eam_cd.o nstencil_full_ghost_bin_2d.o delete_bonds.o compute_global_atom.o pair_tersoff_mod.o ntopo_improper_partial.o region_cone.o improper.o npair_half_bin_newtoff.o compute_com_chunk.o math_eigen.o hashlittle.o min_linesearch.o nstencil_half_multi_2d_tri.o nbin_multi.o fix_press_berendsen.o min.o fix_print.o arg_info.o ntopo_bond_template.o ntopo_dihedral_template.o pair_lcbop.o fix_gravity.o compute_msd_chunk.o fix_nvt_sllod.o ntopo_improper_template.o comm_tiled.o compute_property_local.o force.o modify.o pair_soft.o nstencil_full_multi_3d.o fix_atom_swap.o library.o fix_spring_self.o fix_nve_noforce.o pair_hybrid.o angle_hybrid.o compute_angle.o fix_planeforce.o meam_funcs.o fix_dummy.o balance.o compute_pe_atom.o pair_zbl.o npair_skip_size_off2on.o min_hftn.o fix_halt.o pair_zero.o compute_temp_region.o angle_zero.o fix_wall_harmonic.o atom_vec.o pair_tersoff_zbl.o bond_hybrid.o compute_aggregate_atom.o fix_respa.o pair_comb.o pair_eam.o platform.o nstencil_full_bin_2d.o dump_image.o npair_half_size_bin_newton.o npair_half_respa_bin_newton.o improper_deprecated.o compute_pair.o compute_temp.o compute_pressure.o nbin_standard.o npair_half_multi_newtoff.o fix_widom.o fix_charge_regulation.o npair_half_nsq_newtoff.o delete_atoms.o nstencil_half_bin_3d.o pair_dsmc.o compute_dihedral.o text_file_reader.o pair_vashishta.o meam_dens_final.o nstencil_half_multi_old_2d_tri.o fmtlib_format.o compute_bond_local.o npair_half_respa_bin_newton_tri.o compute_group_group.o ntopo_angle_all.o
mpiicpc -std=c++11 -diag-disable=10441 -diag-disable=2196 -qopenmp -xHost -O2 -fp-model fast=2 -no-prec-div -qoverride-limits -qopt-zmm-usage=high -L/opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/lib/intel64/ main.o -L../../lib/mlip       -L. -llammps_intel_cpu_intelmpi -l_mlip_interface     -std=c++11 -lgfortran  -ldl -ltbbmalloc -lmkl_intel_ilp64 -lmkl_sequential -lmkl_core	 -o ../lmp_intel_cpu_intelmpi
size ../lmp_intel_cpu_intelmpi
   text	   data	    bss	    dec	    hex	filename
11050444	 234840	  14664	11299948	 ac6c6c	../lmp_intel_cpu_intelmpi
make[1]: Leaving directory `/home/nirajd/softwares/mlp/lammps2022/src/Obj_intel_cpu_intelmpi'

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!VOILA!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# if all goes well you can find "lmp_intel_cpu_intelmpi" binary created in the folder.
# to check the linked libraries for the executable.
ldd lmp_intel_cpu_intelmpi

#OUTPUT
	linux-vdso.so.1 =>  (0x00007ffc8ef5f000)
	libgfortran.so.3 => /lib64/libgfortran.so.3 (0x00007f41edfe2000)
	libdl.so.2 => /lib64/libdl.so.2 (0x00007f41eddde000)
	libtbbmalloc.so.2 => /opt/ohpc/pub/compiler/intel/oneapi/tbb/2021.5.1/env/../lib/intel64/gcc4.8/libtbbmalloc.so.2 (0x00007f41edb82000)
	libmkl_intel_ilp64.so.2 => /opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/lib/intel64/libmkl_intel_ilp64.so.2 (0x00007f41ed052000)
	libmkl_sequential.so.2 => /opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/lib/intel64/libmkl_sequential.so.2 (0x00007f41eb638000)
	libmkl_core.so.2 => /opt/ohpc/pub/compiler/intel/oneapi/mkl/2022.0.2/lib/intel64/libmkl_core.so.2 (0x00007f41e7283000)
	libmpicxx.so.12 => /opt/ohpc/pub/compiler/intel/oneapi/mpi/2021.5.1//lib/libmpicxx.so.12 (0x00007f41e7063000)
	libmpifort.so.12 => /opt/ohpc/pub/compiler/intel/oneapi/mpi/2021.5.1//lib/libmpifort.so.12 (0x00007f41e6caf000)
	libmpi.so.12 => /opt/ohpc/pub/compiler/intel/oneapi/mpi/2021.5.1//lib/release/libmpi.so.12 (0x00007f41e547a000)
	librt.so.1 => /lib64/librt.so.1 (0x00007f41e5272000)
	libpthread.so.0 => /lib64/libpthread.so.0 (0x00007f41e5056000)
	libstdc++.so.6 => /lib64/libstdc++.so.6 (0x00007f41e4d4e000)
	libm.so.6 => /lib64/libm.so.6 (0x00007f41e4a4c000)
	libiomp5.so => /opt/ohpc/pub/compiler/intel/oneapi/compiler/2022.0.2/linux/compiler/lib/intel64_lin/libiomp5.so (0x00007f41e462b000)
	libgcc_s.so.1 => /lib64/libgcc_s.so.1 (0x00007f41e4415000)
	libc.so.6 => /lib64/libc.so.6 (0x00007f41e4047000)
	libquadmath.so.0 => /lib64/libquadmath.so.0 (0x00007f41e3e0b000)
	/lib64/ld-linux-x86-64.so.2 (0x00007f41ee304000)
